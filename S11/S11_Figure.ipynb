# %% [markdown]
# <a href="https://colab.research.google.com/github/jagatabhay/TSAI/blob/master/S11/S11_Figure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
x=[0,5,10,15,20,25,30]
y=[0,5,0,5,0,5,0]
plt.plot(x,y)
plt.title('zigzag curve')
plt.axis('off')
plt.show()
