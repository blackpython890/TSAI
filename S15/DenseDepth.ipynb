# %% [markdown]
# <a href="https://colab.research.google.com/github/jagatabhay/TSAI/blob/master/S15/DenseDepth.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/jagatabhay/Deep-Learning.git
# Out:
# Cloning into 'Deep-Learning'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 3356 (delta 8), reused 0 (delta 0), pack-reused 3327
# Receiving objects: 100% (3356/3356), 399.68 MiB | 14.32 MiB/s, done.
# Resolving deltas: 100% (875/875), done.
# Checking out files: 100% (3460/3460), done.

# %%
# !wget https://s3-eu-west-1.amazonaws.com/densedepth/nyu.h5 -O ./Deep-Learning/depth_estimation/nyu.h5
# Out:
# --2020-07-19 19:10:21--  https://s3-eu-west-1.amazonaws.com/densedepth/nyu.h5
# Resolving s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)... 52.218.40.211
# Connecting to s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)|52.218.40.211|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 172897376 (165M) [application/h5]
# Saving to: ‘./Deep-Learning/depth_estimation/nyu.h5’
#
# ./Deep-Learning/dep 100%[===================>] 164.89M  11.2MB/s    in 17s
#
# 2020-07-19 19:10:39 (9.78 MB/s) - ‘./Deep-Learning/depth_estimation/nyu.h5’ saved [172897376/172897376]

# %%
cd Deep-Learning/depth_estimation
# Out:
# /content/Deep-Learning/depth_estimation

# %%
# !python test.py
# Out:
# Using TensorFlow backend.
# Loading model...
#
# Model loaded (nyu.h5).
#
# Loaded (12) images of size (480, 640, 3).
# It took:  43.69745492935181

# %%
from matplotlib import pyplot as plt
from skimage import io

plt.figure(figsize=(20,20))
plt.imshow( io.imread('results.png') )
